# %%
# Unit 8 Project 1
      
#importing libraries 
import pandas as pd
import numpy as np
import seaborn as sns 
import datetime as dt
import os
import matplotlib.pyplot as plt
import alpaca_trade_api as tradeapi
from pathlib import Path
# %matplotlib inline

# %%
print(f"Current Working Directory: {Path.cwd()}")
# Out:
# Current Working Directory: C:\Users\Anirban\Desktop\Python Code folder\Project1\Project_1

# %%
# Reading returns CSV file into DataFrame
DJI_returns = Path("Data/DJI.csv")               
DJI_returns_df = pd.read_csv(DJI_returns,index_col="Date", parse_dates=True, infer_datetime_format=True)
INX_returns = Path("Data/INX.csv")               
INX_returns_df = pd.read_csv(INX_returns,index_col="Date", parse_dates=True, infer_datetime_format=True)
NDAQ_returns = Path("Data/NDAQ.csv")               
NDAQ_returns_df = pd.read_csv(NDAQ_returns,index_col="Date", parse_dates=True, infer_datetime_format=True)
NI225_returns = Path("Data/NI225.csv")               
NI225_returns_df = pd.read_csv(NI225_returns,index_col="Date", parse_dates=True, infer_datetime_format=True)
SHA_returns = Path("Data/SHA.csv")               
SHA_returns_df = pd.read_csv(SHA_returns,index_col="Date", parse_dates=True, infer_datetime_format=True)
SX5E_returns = Path("Data/SX5E.csv")               
SX5E_returns_df = pd.read_csv(SX5E_returns,index_col="Date", parse_dates=True, infer_datetime_format=True)
TSX_returns = Path("Data/TSX.csv")               
TSX_returns_df = pd.read_csv(TSX_returns,index_col="Date", parse_dates=True, infer_datetime_format=True)
UKX_returns = Path("Data/UKX.csv")               
UKX_returns_df = pd.read_csv(UKX_returns,index_col="Date", parse_dates=True, infer_datetime_format=True)
W5000_returns = Path("Data/W5000.csv")               
W5000_returns_df = pd.read_csv(W5000_returns,index_col="Date", parse_dates=True, infer_datetime_format=True)
XJO_returns = Path("Data/XJO.csv")               
XJO_returns_df = pd.read_csv(XJO_returns,index_col="Date", parse_dates=True, infer_datetime_format=True)
FTSEMIB_returns = Path("Data/FTSEMIB.csv")               
FTSEMIB_returns_df = pd.read_csv(FTSEMIB_returns,index_col="Date", parse_dates=True, infer_datetime_format=True)
GOLD_returns = Path("Data/GOLD.csv")               
GOLD_returns_df = pd.read_csv(GOLD_returns,index_col="Date", parse_dates=True, infer_datetime_format=True)

#OIL_returns = Path("Data/OIL.csv")               
#OIL_returns_df = pd.read_csv(OIL_returns,index_col="Date", parse_dates=True, infer_datetime_format=True)


# Sort data by `Date` in ascending order - sort values works too, as does sort index
DJI_returns_df = DJI_returns_df.sort_values("Date")
INX_returns_df = INX_returns_df.sort_values("Date")
NDAQ_returns_df = NDAQ_returns_df.sort_values("Date")
NI225_returns_df = NI225_returns_df.sort_values("Date")
SHA_returns_df = SHA_returns_df.sort_values("Date")
SX5E_returns_df = SX5E_returns_df.sort_values("Date")
TSX_returns_df = TSX_returns_df.sort_values("Date")
UKX_returns_df = UKX_returns_df.sort_values("Date")
W5000_returns_df = W5000_returns_df.sort_values("Date")
XJO_returns_df = XJO_returns_df.sort_values("Date")
FTSEMIB_returns_df = FTSEMIB_returns_df.sort_values("Date")
GOLD_returns_df = GOLD_returns_df.sort_values("Date")
#OIL_returns_df = OIL_returns_df.sort_values("Date")
DJI_returns_df.tail()
#whale_returns_df.count()
# Out:
#             Close
# Date
# 2020-07-15   0.07
# 2020-07-16   0.07
# 2020-07-17   0.06
# 2020-07-20   0.06
# 2020-07-21   0.07

# %%
# Count nulls in whale returns DataFrame
DJI_returns_df.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
DJI_returns_df.dropna(inplace=True)
DJI_returns_df.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
combined_portfolios_df = pd.concat(
    [DJI_returns_df,INX_returns_df, NDAQ_returns_df, NI225_returns_df, SHA_returns_df,SX5E_returns_df,TSX_returns_df,
    UKX_returns_df, W5000_returns_df, XJO_returns_df,FTSEMIB_returns_df, GOLD_returns_df], axis="columns", join="inner"
)
combined_portfolios_df
combined_portfolios_df.head()
# Out:
#             Close  Close  Close     Close  Close    Close  Close    Close  \
# Date
# 2015-10-23   0.13   0.35  58.72  18825.30  13.69  3425.81  56.49  6444.08
# 2015-10-28   0.13   0.32  59.28  18903.02  13.40  3421.09  56.35  6437.80
# 2015-10-30   0.13   0.34  57.89  19083.10  13.30  3418.23  55.34  6361.09
# 2015-11-09   0.11   0.32  57.68  19642.74  12.70  3418.36  55.01  6295.16
# 2015-11-20   0.11   0.29  59.97  19879.81  15.09  3452.45  55.87  6334.63
#
#                Close   Close     Close  Close
# Date
# 2015-10-23  21614.06  5351.6  22736.86   7.75
# 2015-10-28  21771.95  5335.2  22686.24   7.69
# 2015-10-30  21648.51  5239.4  22442.51   7.69
# 2015-11-09  21645.04  5119.5  22107.30   7.36
# 2015-11-20  21681.31  5256.1  22140.14   7.19

# %%
# Rename Column from Close to "S&P 500"
combined_portfolios_df.columns.values[0] = "DJI"
combined_portfolios_df.columns.values[1] = "INX"
combined_portfolios_df.columns.values[2] = "NDAQ"
combined_portfolios_df.columns.values[3] = "NI225"
combined_portfolios_df.columns.values[4] = "SHA"
combined_portfolios_df.columns.values[5] = "SX5E"
combined_portfolios_df.columns.values[6] = "TSX"
combined_portfolios_df.columns.values[7] = "UKX"
combined_portfolios_df.columns.values[8] = "W5000"
combined_portfolios_df.columns.values[9] = "XJO"
combined_portfolios_df.columns.values[10] = "FTSEMIB"
combined_portfolios_df.columns.values[11] = "GOLD"
combined_portfolios_df.head()
# Out:
#              DJI   INX   NDAQ     NI225    SHA     SX5E    TSX      UKX  \
# Date
# 2015-10-23  0.13  0.35  58.72  18825.30  13.69  3425.81  56.49  6444.08
# 2015-10-28  0.13  0.32  59.28  18903.02  13.40  3421.09  56.35  6437.80
# 2015-10-30  0.13  0.34  57.89  19083.10  13.30  3418.23  55.34  6361.09
# 2015-11-09  0.11  0.32  57.68  19642.74  12.70  3418.36  55.01  6295.16
# 2015-11-20  0.11  0.29  59.97  19879.81  15.09  3452.45  55.87  6334.63
#
#                W5000     XJO   FTSEMIB  GOLD
# Date
# 2015-10-23  21614.06  5351.6  22736.86  7.75
# 2015-10-28  21771.95  5335.2  22686.24  7.69
# 2015-10-30  21648.51  5239.4  22442.51  7.69
# 2015-11-09  21645.04  5119.5  22107.30  7.36
# 2015-11-20  21681.31  5256.1  22140.14  7.19

# %%
# Check Data Types in S&P 500 historical price DataFrame
combined_portfolios_df.dtypes
# Out:
# DJI        float64
# INX        float64
# NDAQ       float64
# NI225      float64
# SHA        float64
# SX5E       float64
# TSX        float64
# UKX        float64
# W5000      float64
# XJO        float64
# FTSEMIB    float64
# GOLD       float64
# dtype: object

# %%
# Calculate Daily Returns and dropping null values
combined_portfolios_df = combined_portfolios_df.pct_change().dropna().copy()
combined_portfolios_df.head()
# Out:
#                  DJI       INX      NDAQ     NI225       SHA      SX5E  \
# Date
# 2015-10-28  0.000000 -0.085714  0.009537  0.004128 -0.021183 -0.001378
# 2015-10-30  0.000000  0.062500 -0.023448  0.009527 -0.007463 -0.000836
# 2015-11-09 -0.153846 -0.058824 -0.003628  0.029326 -0.045113  0.000038
# 2015-11-20  0.000000 -0.093750  0.039702  0.012069  0.188189  0.009973
# 2015-11-25  0.000000 -0.068966 -0.025346 -0.001621  0.053678  0.002784
#
#                  TSX       UKX     W5000       XJO   FTSEMIB      GOLD
# Date
# 2015-10-28 -0.002478 -0.000975  0.007305 -0.003065 -0.002226 -0.007742
# 2015-10-30 -0.017924 -0.011916 -0.005670 -0.017956 -0.010744  0.000000
# 2015-11-09 -0.005963 -0.010365 -0.000160 -0.022884 -0.014936 -0.042913
# 2015-11-20  0.015634  0.006270  0.001676  0.026682  0.001485 -0.023098
# 2015-11-25  0.005549  0.000475  0.002793 -0.011872  0.009896  0.026426

# %%
#Portfolio Analysis - calculate and visualize performance and risk metrics for the portfolios

# Plotting the daily returns and cumulative returns.
combined_portfolios_df.plot(title='Daily Returns', figsize=(20,10))

# %%
# Calculate cumulative returns
cumulative_returns = (1 + combined_portfolios_df).cumprod()
cumulative_returns.head()
# Out:
#                  DJI       INX      NDAQ     NI225       SHA      SX5E  \
# Date
# 2015-10-28  1.000000  0.914286  1.009537  1.004128  0.978817  0.998622
# 2015-10-30  1.000000  0.971429  0.985865  1.013694  0.971512  0.997787
# 2015-11-09  0.846154  0.914286  0.982289  1.043422  0.927684  0.997825
# 2015-11-20  0.846154  0.828571  1.021287  1.056016  1.102264  1.007776
# 2015-11-25  0.846154  0.771429  0.995402  1.054304  1.161432  1.010581
#
#                  TSX       UKX     W5000       XJO   FTSEMIB      GOLD
# Date
# 2015-10-28  0.997522  0.999025  1.007305  0.996935  0.997774  0.992258
# 2015-10-30  0.979642  0.987122  1.001594  0.979034  0.987054  0.992258
# 2015-11-09  0.973801  0.976890  1.001433  0.956630  0.972311  0.949677
# 2015-11-20  0.989025  0.983015  1.003111  0.982155  0.973755  0.927742
# 2015-11-25  0.994512  0.983483  1.005913  0.970495  0.983391  0.952258

# %%
# Plotting cumulative returns
cumulative_returns.plot(title='Cumulative Returns', figsize=(20,10))

# %%
# Box plot to visually show risk
combined_portfolios_df.boxplot(figsize=(20,10))

# %%
# Calculate the standard deviation for each portfolio
combined_portfolios_std = combined_portfolios_df.std()
combined_portfolios_std.head(10)
# Out:
# DJI      0.118213
# INX      0.063602
# NDAQ     0.022085
# NI225    0.018715
# SHA      0.036457
# SX5E     0.019022
# TSX      0.020007
# UKX      0.016475
# W5000    0.017351
# XJO      0.015193
# dtype: float64

# %%
# Which portfolios are riskier than the S&P 500?
#for i in range(len(combined_portfolios_std)):
 #   if(combined_portfolios_std[i] > combined_portfolios_std['S&P 500']):      
  #      tag = "True"  
   #     name = combined_portfolios_std.index[i]  
   # else:
    #    tag = "False"
     #   name = combined_portfolios_std.index[i]  
    #print(f"{name} {tag}")
#The Standard deviation of TIGER GLOBAL MANAGEMENT LLC and BERKSHIRE HATHAWAY INC is higher than the STD of S&P 500
# Out:
# SOROS FUND MANAGEMENT LLC False
# PAULSON & CO.INC.  False
# TIGER GLOBAL MANAGEMENT LLC True
# BERKSHIRE HATHAWAY INC True
# Algo 1 False
# Algo 2 False
# S&P 500 False

# %%
# Calculate the annualized standard deviation (252 trading days)
combined_portfolios_annualized_std = combined_portfolios_std * np.sqrt(252)
combined_portfolios_annualized_std.head(7)
# Out:
# DJI      1.876580
# INX      1.009654
# NDAQ     0.350581
# NI225    0.297096
# SHA      0.578738
# SX5E     0.301960
# TSX      0.317599
# dtype: float64

# %%
#Rolling Statistics - Risk changes over time. Analyze the rolling statistics for Risk and Beta.

#Calculate and plot the rolling standard deviation for the S&P 500 and whale portfolios using a 21 trading day window

#sorting before the moving averages
combined_portfolios_df = combined_portfolios_df.sort_index()
#Calculating rolling std using 21 trading day window
rolling_std = combined_portfolios_df.rolling(window=21).std().plot(title = '21 Day Rolling Standard Deviation', figsize =[20,10])
#plotting
rolling_std

# %%
#Construct a correlation table
correlation_table = combined_portfolios_df.corr()
correlation_table
# Out:
#               DJI       INX      NDAQ     NI225       SHA      SX5E       TSX  \
# DJI      1.000000  0.057527  0.154344  0.195380  0.077134  0.149665  0.114624
# INX      0.057527  1.000000  0.026266  0.116937  0.162690  0.177930  0.128090
# NDAQ     0.154344  0.026266  1.000000  0.279229  0.147393  0.422692  0.418119
# NI225    0.195380  0.116937  0.279229  1.000000  0.400802  0.653156  0.550987
# SHA      0.077134  0.162690  0.147393  0.400802  1.000000  0.593254  0.447879
# SX5E     0.149665  0.177930  0.422692  0.653156  0.593254  1.000000  0.785758
# TSX      0.114624  0.128090  0.418119  0.550987  0.447879  0.785758  1.000000
# UKX      0.157530  0.150884  0.461480  0.543844  0.482942  0.864643  0.801347
# W5000    0.141485  0.102945  0.686346  0.449977  0.377057  0.692535  0.635701
# XJO      0.168945  0.106864  0.454255  0.529900  0.310168  0.584171  0.621806
# FTSEMIB  0.115297  0.143762  0.352152  0.591831  0.537153  0.901758  0.669632
# GOLD     0.052508 -0.061468  0.111123 -0.058731 -0.055237 -0.033533  0.162000
#
#               UKX     W5000       XJO   FTSEMIB      GOLD
# DJI      0.157530  0.141485  0.168945  0.115297  0.052508
# INX      0.150884  0.102945  0.106864  0.143762 -0.061468
# NDAQ     0.461480  0.686346  0.454255  0.352152  0.111123
# NI225    0.543844  0.449977  0.529900  0.591831 -0.058731
# SHA      0.482942  0.377057  0.310168  0.537153 -0.055237
# SX5E     0.864643  0.692535  0.584171  0.901758 -0.033533
# TSX      0.801347  0.635701  0.621806  0.669632  0.162000
# UKX      1.000000  0.691955  0.612861  0.749919  0.099407
# W5000    0.691955  1.000000  0.598466  0.603352  0.093067
# XJO      0.612861  0.598466  1.000000  0.470315  0.048855
# FTSEMIB  0.749919  0.603352  0.470315  1.000000 -0.071131
# GOLD     0.099407  0.093067  0.048855 -0.071131  1.000000

# %%
#correlation matrix using a heatmap
sns.heatmap(correlation_table, vmin=-1, vmax=1)

# %%
#Calculate Beta for a single portfolio compared to the total market (S&P 500)
# (Your graph may differ, dependent upon which portfolio you are comparing)

#Calculate the total variance of the S&P 500 daily returns.
#total_variance =combined_portfolios_df["S&P 500"].var()
#Calculate the overall covariances of BERKSHIRE HATHAWAY INC stock to that of the S&P 500. 
#cov_berkshire = combined_portfolios_df['BERKSHIRE HATHAWAY INC'].cov(combined_portfolios_df['S&P 500'])
#Calculate the overall beta values of each social media stock.
#beta_berkshire = cov_berkshire / total_variance
#print(beta_berkshire)
# Out:
# 1.1347891297491723

# %%
# Calculate a rolling window
#rolling_variance = combined_portfolios_df["S&P 500"].rolling(window=30).var()
#rolling_covariance = combined_portfolios_df["BERKSHIRE HATHAWAY INC"].rolling(window=30).cov(combined_portfolios_df["S&P 500"])
#rolling_beta = rolling_covariance / rolling_variance
#rolling_beta.plot(title="Berkshire Hathway Inc. Beta", figsize=[20,10])

# %%
# Calculate a rolling window using the exponentially weighted moving average.
# rolling_ewma = combined_portfolios_df.apply(lambda x: x.ewm(halflife=21).std()).plot(figsize=[20,10])
# rolling_ewma

# %%
#5. Calculate the Sharpe ratios by computing the quotient of `annualized average return` and `annualized standard deviation`.
sharpe_ratios = (combined_portfolios_df.mean() * 252) / (combined_portfolios_df.std()* np.sqrt(252))
sharpe_ratios
# Out:
# DJI        0.726441
# INX        0.671366
# NDAQ       1.237699
# NI225      0.457697
# SHA       -0.311022
# SX5E       0.124675
# TSX        0.214710
# UKX        0.075921
# W5000      0.870073
# XJO        0.353867
# FTSEMIB    0.028278
# GOLD       1.261285
# dtype: float64

# %%
#6. Plot the Sharpe ratios using a bar chart.
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")

# %%
# Set the random seed for resutls reproducibility (for testing purposes only)
np.random.seed(42)

# %%
# # Load .env enviroment variables
# from dotenv import load_dotenv
# load_dotenv()

# # Set Alpaca API key and secret
# alpaca_api_key = os.getenv("ALPACA_API_KEY")
# alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

# # Create the Alpaca API object
# api = tradeapi.REST(
#     alpaca_api_key,
#     alpaca_secret_key,
#     api_version="v2")

# %%
# # Subset your tickers, then pull returns data:
# # Set the ticker
# ticker = ["SPY", "AGG"]

# # Set timeframe to '1D'
# timeframe = "1D"

# # Set start and end datetimes of 1 year, between now and 365 days ago.
# start_date = pd.Timestamp('2019-01-01', tz='America/New_York').isoformat()
# end_date = pd.Timestamp('2019-12-31', tz='America/New_York').isoformat()

# # Get 1 year's worth of historical data for SPY and AGG
# df = api.get_barset(
#     ticker,
#     timeframe,
#     limit=None,
#     start=start_date,
#     end=end_date,
#     after=None,
#     until=None,
# ).df

# # Drop unnecessary columns
# df = df.drop(
#     columns=['open', 'high', 'low', 'volume'],
#     level=1
# )
combined_portfolios_df.count()
combined_portfolios_df.head()
# Out:
#                  DJI       INX      NDAQ     NI225       SHA      SX5E  \
# Date
# 2015-10-28  0.000000 -0.085714  0.009537  0.004128 -0.021183 -0.001378
# 2015-10-30  0.000000  0.062500 -0.023448  0.009527 -0.007463 -0.000836
# 2015-11-09 -0.153846 -0.058824 -0.003628  0.029326 -0.045113  0.000038
# 2015-11-20  0.000000 -0.093750  0.039702  0.012069  0.188189  0.009973
# 2015-11-25  0.000000 -0.068966 -0.025346 -0.001621  0.053678  0.002784
#
#                  TSX       UKX     W5000       XJO   FTSEMIB      GOLD
# Date
# 2015-10-28 -0.002478 -0.000975  0.007305 -0.003065 -0.002226 -0.007742
# 2015-10-30 -0.017924 -0.011916 -0.005670 -0.017956 -0.010744  0.000000
# 2015-11-09 -0.005963 -0.010365 -0.000160 -0.022884 -0.014936 -0.042913
# 2015-11-20  0.015634  0.006270  0.001676  0.026682  0.001485 -0.023098
# 2015-11-25  0.005549  0.000475  0.002793 -0.011872  0.009896  0.026426

# %%
combined_portfolios_df_post= combined_portfolios_df['2015-01-01':'2016-12-20']
combined_portfolios_df_post.count()


#Analysis 
#1. Split the Data into 

#Zeldi and Richa
    # Pre 1 - Jan 1 2015 - Dec 31 2019, Post 1 - Jan 1 2015 - Jul 23 2020

#Amit & Mihir
    # Pre 2 - Mar 1 2019 - Feb 28 2020, Post 2 - July 1 2019 - Jun 30 2020
#2.Take each csv file and run a monte carlo 

# Use the `mean` function to calculate the mean of daily returns for "SPY", "AGG"
# avg_daily_return_spy = daily_returns.mean()['SPY']['close']
# avg_daily_return_agg = daily_returns.mean()['AGG']['close']
# print(f"Average Daily Return of SPY stock is: {avg_daily_return_spy}")
# print(f"Average Daily Return of AGG stock is: {avg_daily_return_agg}")
# Out:
# DJI        94
# INX        94
# NDAQ       94
# NI225      94
# SHA        94
# SX5E       94
# TSX        94
# UKX        94
# W5000      94
# XJO        94
# FTSEMIB    94
# GOLD       94
# dtype: int64

# %%
# Compute daily volatility - change it 
std_dev_daily_return_spy = daily_returns.std()['SPY']['close']
std_dev_daily_return_agg = daily_returns.std()['AGG']['close']
print(f"Daily Volatility of SPY stock is: {std_dev_daily_return_spy}")
print(f"Daily Volatility of AGG stock is: {std_dev_daily_return_agg}")

# %%
# Save the last day's closing price - change it 
spy_last_price = df['SPY']['close'][-1]
agg_last_price = df['AGG']['close'][-1]
print(f"Last Day's Closing Price of SPY stock is: {spy_last_price}")
print(f"Last Day's Closing Price of AGG stock is: {agg_last_price}")

# %%
# Setup the Monte Carlo Parameters
number_simulations = 500
number_records1 = 252 * 5
number_records2 = 252 * 20
#number_records3 = 252 * 20

# Initialize empty DataFrame to hold simulated prices for each simulation
monte_carlo = pd.DataFrame()
portfolio_cumulative_returns = pd.DataFrame()

# %%
# Run the Monte Carlo Simulation

# Run the simulation of projecting stock prices for the next trading year, 600` times
for n in range(number_simulations):

    # Initialize the simulated prices list with the last closing price of `SPY` and `AGG`
    simulated_spy_prices = [spy_last_price]
    simulated_agg_prices = [agg_last_price]
    
    # Simulate the returns for 252 * 30 days
    for i in range(number_records):
        
        # Calculate the simulated price using the last price within the list
        simulated_spy_price = simulated_spy_prices[-1] * (1 + np.random.normal(avg_daily_return_spy, std_dev_daily_return_spy))
        simulated_agg_price = simulated_agg_prices[-1] * (1 + np.random.normal(avg_daily_return_agg, std_dev_daily_return_agg))
        
        # Append the simulated price to the list
        simulated_spy_prices.append(simulated_spy_price)
        simulated_agg_prices.append(simulated_agg_price)
    
    # Append the simulated prices of each simulation to DataFrame
    monte_carlo["SPY prices"] = pd.Series(simulated_spy_prices)
    monte_carlo["AGG prices"] = pd.Series(simulated_agg_prices)
    
    # Calculate the daily returns of simulated prices
    simulated_daily_returns = monte_carlo.pct_change()
    
    # Set the portfolio weights (60% SPY; 40% AGG)
    weights = [0.60, 0.40]

    # Use the `dot` function with the weights to multiply weights with each column's simulated daily returns
    portfolio_daily_returns = simulated_daily_returns.dot(weights)
    
    # Calculate the normalized, cumulative return series
    portfolio_cumulative_returns[n] = (1 + portfolio_daily_returns.fillna(0)).cumprod()
